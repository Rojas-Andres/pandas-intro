# %%
import pandas as pd

# %%
# pip install pandas

# %%
df = pd.read_csv('personas.csv')

# %%
df
# Out:
#        id first_name   last_name                           email      gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com      Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com        Male
# 2       3      Robby      Scyner                 rscyner2@nhs.uk     Agender
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com  Non-binary
# 4       5     Yolane      Wipper                ywipper4@nih.gov      Female
# ..    ...        ...         ...                             ...         ...
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com        Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com      Female
# 997   998   Antonina      Boyall               aboyallrp@icio.us      Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com        Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn      Female
#
#           ip_address
# 0    107.245.207.138
# ...

# %%
df.head()
# Out:
#    id first_name   last_name                          email      gender  \
# 0   1     Pearle      Spacey              pspacey0@cnbc.com      Female
# 1   2    Brockie  Bladesmith  bbladesmith1@wunderground.com        Male
# 2   3      Robby      Scyner                rscyner2@nhs.uk     Agender
# 3   4    Harland    Lampaert    hlampaert3@businessweek.com  Non-binary
# 4   5     Yolane      Wipper               ywipper4@nih.gov      Female
#
#         ip_address
# 0  107.245.207.138
# 1      84.97.7.155
# 2    17.144.34.144
# 3  146.153.179.154
# 4    198.86.74.199

# %%
df.tail()
# Out:
#        id first_name last_name                           email  gender  \
# 995   996      Tynan   Scroggs            tscroggsrn@lycos.com    Male
# 996   997    Elberta   Hildred          ehildredro@vinaora.com  Female
# 997   998   Antonina    Boyall               aboyallrp@icio.us  Female
# 998   999        Sax  Lovelace  slovelacerq@chicagotribune.com    Male
# 999  1000        Gay    Raddon         graddonrr@people.com.cn  Female
#
#           ip_address
# 995   172.29.104.249
# 996     64.134.2.178
# 997    190.4.195.179
# 998   110.229.109.39
# 999  155.175.119.151

# %% [markdown]
# ### Mostrar los registros por columna

# %%
df["first_name"]
# Out:
# 0        Pearle
# 1       Brockie
# 2         Robby
# 3       Harland
# 4        Yolane
#          ...
# 995       Tynan
# 996     Elberta
# 997    Antonina
# 998         Sax
# 999         Gay
# Name: first_name, Length: 1000, dtype: object

# %%
df[["first_name","email"]]
# Out:
#     first_name                           email
# 0       Pearle               pspacey0@cnbc.com
# 1      Brockie   bbladesmith1@wunderground.com
# 2        Robby                 rscyner2@nhs.uk
# 3      Harland     hlampaert3@businessweek.com
# 4       Yolane                ywipper4@nih.gov
# ..         ...                             ...
# 995      Tynan            tscroggsrn@lycos.com
# 996    Elberta          ehildredro@vinaora.com
# 997   Antonina               aboyallrp@icio.us
# 998        Sax  slovelacerq@chicagotribune.com
# 999        Gay         graddonrr@people.com.cn
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Filtrar por condicional

# %%
df[df.id > 100]
# Out:
#        id  first_name last_name                           email  gender  \
# 100   101     Jillian  Challens        jchallens2s@symantec.com  Female
# 101   102    Kellyann  McGunley    kmcgunley2t@biblegateway.com  Female
# 102   103   Simonette  Bradbeer        sbradbeer2u@freewebs.com  Female
# 103   104     Domenic    Thorne                dthorne2v@w3.org    Male
# 104   105  Antonietta   Ianetti           aianetti2w@spiegel.de  Female
# ..    ...         ...       ...                             ...     ...
# 995   996       Tynan   Scroggs            tscroggsrn@lycos.com    Male
# 996   997     Elberta   Hildred          ehildredro@vinaora.com  Female
# 997   998    Antonina    Boyall               aboyallrp@icio.us  Female
# 998   999         Sax  Lovelace  slovelacerq@chicagotribune.com    Male
# 999  1000         Gay    Raddon         graddonrr@people.com.cn  Female
#
#           ip_address
# 100      165.29.0.19
# 101     46.16.56.138
# 102      128.6.71.43
# ...

# %%
df[df["id"] > 100]
# Out:
#        id  first_name last_name                           email  gender  \
# 100   101     Jillian  Challens        jchallens2s@symantec.com  Female
# 101   102    Kellyann  McGunley    kmcgunley2t@biblegateway.com  Female
# 102   103   Simonette  Bradbeer        sbradbeer2u@freewebs.com  Female
# 103   104     Domenic    Thorne                dthorne2v@w3.org    Male
# 104   105  Antonietta   Ianetti           aianetti2w@spiegel.de  Female
# ..    ...         ...       ...                             ...     ...
# 995   996       Tynan   Scroggs            tscroggsrn@lycos.com    Male
# 996   997     Elberta   Hildred          ehildredro@vinaora.com  Female
# 997   998    Antonina    Boyall               aboyallrp@icio.us  Female
# 998   999         Sax  Lovelace  slovelacerq@chicagotribune.com    Male
# 999  1000         Gay    Raddon         graddonrr@people.com.cn  Female
#
#           ip_address
# 100      165.29.0.19
# 101     46.16.56.138
# 102      128.6.71.43
# ...

# %%
df[(df["id"]>10) & (df["gender"]=="Male")]
# Out:
#       id first_name  last_name                           email gender  \
# 10    11   Filberto   Etherton            fethertona@bbc.co.uk   Male
# 11    12      Irvin      Awdry     iawdryb@businessinsider.com   Male
# 19    20       Gris    Ewbanke           gewbankej@myspace.com   Male
# 20    21     Zollie     Bowles         zbowlesk@slideshare.net   Male
# 22    23      Miner     Billam           mbillamm@marriott.com   Male
# ..   ...        ...        ...                             ...    ...
# 987  988    Bryanty    Curryer             bcurryerrf@etsy.com   Male
# 989  990        Cly     Prowse           cprowserh@yahoo.co.jp   Male
# 993  994       Elmo  Ivancevic            eivancevicrl@last.fm   Male
# 995  996      Tynan    Scroggs            tscroggsrn@lycos.com   Male
# 998  999        Sax   Lovelace  slovelacerq@chicagotribune.com   Male
#
#           ip_address
# 10    59.166.142.144
# 11   172.165.149.112
# 19     16.174.30.133
# 20    40.136.176.140
# ...

# %%
df[df["email"].str.contains(".com")]
# Out:
#        id first_name   last_name                           email       gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com       Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com         Male
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com   Non-binary
# 5       6      Nisse    Poinsett         npoinsett5@bluehost.com  Genderfluid
# 6       7      Uriel     Choffin              uchoffin6@ehow.com         Male
# ..    ...        ...         ...                             ...          ...
# 994   995   Beatrisa    Chalmers           bchalmersrm@slate.com       Female
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com         Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com       Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com         Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn       Female
#
#           ip_address
# ...

# %%
# df[df["email"].str.contains(".com")]
df[df.email.str.contains(".com")]
# Out:
#        id first_name   last_name                           email       gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com       Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com         Male
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com   Non-binary
# 5       6      Nisse    Poinsett         npoinsett5@bluehost.com  Genderfluid
# 6       7      Uriel     Choffin              uchoffin6@ehow.com         Male
# ..    ...        ...         ...                             ...          ...
# 994   995   Beatrisa    Chalmers           bchalmersrm@slate.com       Female
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com         Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com       Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com         Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn       Female
#
#           ip_address
# ...

# %%
df[df.email.str.startswith('g')]
# Out:
#        id  first_name      last_name                                email  \
# 14     15   Gertrudis       Seiffert                   gseifferte@ucoz.ru
# 19     20        Gris        Ewbanke                gewbankej@myspace.com
# 26     27      Georgi      Rubenovic                  grubenovicq@mtv.com
# 59     60    Gonzales        Oakland               goakland1n@state.tx.us
# 90     91       Garek       Grunguer                ggrunguer2i@hc360.com
# 122   123    Gilberto      Bullivent  gbullivent3e@networkadvertising.org
# 126   127   Gerladina       Danielis                   gdanielis3i@nhs.uk
# 141   142   Guenevere        Rannald               grannald3x@cornell.edu
# 143   144    Gertruda        O'Neary                 goneary3z@usnews.com
# 163   164       Gipsy           Venn                   gvenn4j@jalbum.net
# 194   195      Giraud     Dudlestone             gdudlestone5e@ustream.tv
# 195   196      Gretal      Seabridge  gseabridge5f@nationalgeographic.com
# ...

# %%
#df[(df["id"]>10) & (df["gender"]=="Male")]
df[(df.id > 10 ) & (df.gender=="Male")]
# Out:
#       id first_name  last_name                           email gender  \
# 10    11   Filberto   Etherton            fethertona@bbc.co.uk   Male
# 11    12      Irvin      Awdry     iawdryb@businessinsider.com   Male
# 19    20       Gris    Ewbanke           gewbankej@myspace.com   Male
# 20    21     Zollie     Bowles         zbowlesk@slideshare.net   Male
# 22    23      Miner     Billam           mbillamm@marriott.com   Male
# ..   ...        ...        ...                             ...    ...
# 987  988    Bryanty    Curryer             bcurryerrf@etsy.com   Male
# 989  990        Cly     Prowse           cprowserh@yahoo.co.jp   Male
# 993  994       Elmo  Ivancevic            eivancevicrl@last.fm   Male
# 995  996      Tynan    Scroggs            tscroggsrn@lycos.com   Male
# 998  999        Sax   Lovelace  slovelacerq@chicagotribune.com   Male
#
#           ip_address
# 10    59.166.142.144
# 11   172.165.149.112
# 19     16.174.30.133
# 20    40.136.176.140
# ...

# %%
df[~df.email.str.contains(".com")]
# Out:
#       id first_name     last_name                         email       gender  \
# 2      3      Robby        Scyner               rscyner2@nhs.uk      Agender
# 4      5     Yolane        Wipper              ywipper4@nih.gov       Female
# 7      8    Niccolo           Caw           ncaw7@imageshack.us         Male
# 8      9     Frasco      Ibbitson            fibbitson8@last.fm         Male
# 10    11   Filberto      Etherton          fethertona@bbc.co.uk         Male
# ..   ...        ...           ...                           ...          ...
# 989  990        Cly        Prowse         cprowserh@yahoo.co.jp         Male
# 991  992     Mariel       Absalom    mabsalomrj@sourceforge.net       Female
# 992  993    Merilee  Childerhouse  mchilderhouserk@geocities.jp  Genderfluid
# 993  994       Elmo     Ivancevic          eivancevicrl@last.fm         Male
# 997  998   Antonina        Boyall             aboyallrp@icio.us       Female
#
#           ip_address
# 2      17.144.34.144
# ...

# %% [markdown]
# ### Multiples filtros

# %%
genders = ["Male","Female"]

df[df.gender.isin(genders)]
# Out:
#        id first_name   last_name                           email  gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com  Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com    Male
# 4       5     Yolane      Wipper                ywipper4@nih.gov  Female
# 6       7      Uriel     Choffin              uchoffin6@ehow.com    Male
# 7       8    Niccolo         Caw             ncaw7@imageshack.us    Male
# ..    ...        ...         ...                             ...     ...
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com    Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com  Female
# 997   998   Antonina      Boyall               aboyallrp@icio.us  Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com    Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn  Female
#
#           ip_address
# 0    107.245.207.138
# 1        84.97.7.155
# 4      198.86.74.199
# ...

# %% [markdown]
# ## Filtrar por filas

# %%
df.iloc[998:]
# Out:
#        id first_name last_name                           email  gender  \
# 998   999        Sax  Lovelace  slovelacerq@chicagotribune.com    Male
# 999  1000        Gay    Raddon         graddonrr@people.com.cn  Female
#
#           ip_address
# 998   110.229.109.39
# 999  155.175.119.151

# %%
df.iloc[3]
# Out:
# id                                      4
# first_name                        Harland
# last_name                        Lampaert
# email         hlampaert3@businessweek.com
# gender                         Non-binary
# ip_address                146.153.179.154
# Name: 3, dtype: object

# %%
df.loc[[1,998],["first_name","email"]]
# Out:
#     first_name                           email
# 1      Brockie   bbladesmith1@wunderground.com
# 998        Sax  slovelacerq@chicagotribune.com

# %%
def multiplicacion(id):
    new_id = id * 10
    return new_id 

df["multiplicacion"] = df["id"].apply(multiplicacion)

# %%
df
# Out:
#        id first_name   last_name                           email      gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com      Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com        Male
# 2       3      Robby      Scyner                 rscyner2@nhs.uk     Agender
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com  Non-binary
# 4       5     Yolane      Wipper                ywipper4@nih.gov      Female
# ..    ...        ...         ...                             ...         ...
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com        Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com      Female
# 997   998   Antonina      Boyall               aboyallrp@icio.us      Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com        Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn      Female
#
#           ip_address  multiplicacion
# ...

# %%
def concatenar(first_name):
    new_first_name = f"{first_name} new"
    return new_first_name

df["concatenar"] = df["first_name"].apply(concatenar)

# %%
df
# Out:
#        id first_name   last_name                           email      gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com      Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com        Male
# 2       3      Robby      Scyner                 rscyner2@nhs.uk     Agender
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com  Non-binary
# 4       5     Yolane      Wipper                ywipper4@nih.gov      Female
# ..    ...        ...         ...                             ...         ...
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com        Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com      Female
# 997   998   Antonina      Boyall               aboyallrp@icio.us      Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com        Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn      Female
#
# ...

# %%
df["full_name"] = df["first_name"] + df["last_name"]

# %%
df
# Out:
#        id first_name   last_name                           email      gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com      Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com        Male
# 2       3      Robby      Scyner                 rscyner2@nhs.uk     Agender
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com  Non-binary
# 4       5     Yolane      Wipper                ywipper4@nih.gov      Female
# ..    ...        ...         ...                             ...         ...
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com        Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com      Female
# 997   998   Antonina      Boyall               aboyallrp@icio.us      Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com        Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn      Female
#
# ...

# %% [markdown]
# ## Eliminar columna del dataframe

# %%
df2 = df.drop(["full_name"],axis=1)

# %%
df2
# Out:
#        id first_name   last_name                           email      gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com      Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com        Male
# 2       3      Robby      Scyner                 rscyner2@nhs.uk     Agender
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com  Non-binary
# 4       5     Yolane      Wipper                ywipper4@nih.gov      Female
# ..    ...        ...         ...                             ...         ...
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com        Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com      Female
# 997   998   Antonina      Boyall               aboyallrp@icio.us      Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com        Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn      Female
#
# ...

# %%
df2["full_name"] = df2["first_name"] + " " +df2["last_name"]

# %%
df2
# Out:
#        id first_name   last_name                           email      gender  \
# 0       1     Pearle      Spacey               pspacey0@cnbc.com      Female
# 1       2    Brockie  Bladesmith   bbladesmith1@wunderground.com        Male
# 2       3      Robby      Scyner                 rscyner2@nhs.uk     Agender
# 3       4    Harland    Lampaert     hlampaert3@businessweek.com  Non-binary
# 4       5     Yolane      Wipper                ywipper4@nih.gov      Female
# ..    ...        ...         ...                             ...         ...
# 995   996      Tynan     Scroggs            tscroggsrn@lycos.com        Male
# 996   997    Elberta     Hildred          ehildredro@vinaora.com      Female
# 997   998   Antonina      Boyall               aboyallrp@icio.us      Female
# 998   999        Sax    Lovelace  slovelacerq@chicagotribune.com        Male
# 999  1000        Gay      Raddon         graddonrr@people.com.cn      Female
#
# ...

# %% [markdown]
# ## Eliminar filas de un dataframe

# %%
df2.drop([1,2],axis=0)
# Out:
#        id first_name last_name                           email       gender  \
# 0       1     Pearle    Spacey               pspacey0@cnbc.com       Female
# 3       4    Harland  Lampaert     hlampaert3@businessweek.com   Non-binary
# 4       5     Yolane    Wipper                ywipper4@nih.gov       Female
# 5       6      Nisse  Poinsett         npoinsett5@bluehost.com  Genderfluid
# 6       7      Uriel   Choffin              uchoffin6@ehow.com         Male
# ..    ...        ...       ...                             ...          ...
# 995   996      Tynan   Scroggs            tscroggsrn@lycos.com         Male
# 996   997    Elberta   Hildred          ehildredro@vinaora.com       Female
# 997   998   Antonina    Boyall               aboyallrp@icio.us       Female
# 998   999        Sax  Lovelace  slovelacerq@chicagotribune.com         Male
# 999  1000        Gay    Raddon         graddonrr@people.com.cn       Female
#
# ...
